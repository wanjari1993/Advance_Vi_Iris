# %% [markdown]
# # #Iris Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **CSV File Import**

# %%
irisds=pd.read_csv(r"D:\Naresh IT\New Notes\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv")

# %%
irisds
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
irisds.head(30)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
irisds.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
irisds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
irisds.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
irisds
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
irisds.drop('Id',axis=1,inplace=True)

# %%
irisds
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
irisds['PetalWidthCm'].value_counts()
# Out:
# 0.2    28
# 1.3    13
# 1.8    12
# 1.5    12
# 1.4     8
# 2.3     8
# 1.0     7
# 0.4     7
# 0.3     7
# 0.1     6
# 2.1     6
# 2.0     6
# 1.2     5
# 1.9     5
# 1.6     4
# 2.5     3
# 2.2     3
# 2.4     3
# 1.1     3
# 1.7     2
# 0.6     1
# 0.5     1
# Name: PetalWidthCm, dtype: int64

# %% [markdown]
# **Bar Plot**

# %%
sns.countplot('Species', data=irisds)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %%
irisds.head(10)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
# 5            5.4           3.9            1.7           0.4  Iris-setosa
# 6            4.6           3.4            1.4           0.3  Iris-setosa
# 7            5.0           3.4            1.5           0.2  Iris-setosa
# 8            4.4           2.9            1.4           0.2  Iris-setosa
# 9            4.9           3.1            1.5           0.1  Iris-setosa

# %%
irisds.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %% [markdown]
# **Joint Plot**

# %%
a=sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data=irisds)

# %%
sns.jointplot(data=irisds, x='PetalLengthCm', y='PetalWidthCm',kind='reg')

# %%
sns.jointplot(data=irisds, x='PetalLengthCm', y='PetalWidthCm',kind='scatter')

# %%
sns.jointplot(data=irisds, x='PetalLengthCm', y='PetalWidthCm',kind='kde')

# %%
sns.jointplot(data=irisds, x='PetalLengthCm', y='PetalWidthCm',kind='hist')

# %%
sns.jointplot(data=irisds, x='SepalWidthCm', y='PetalWidthCm',kind='hex')

# %% [markdown]
# **FacetGrid Plot**

# %%
# %matplotlib inline

# %%
sns.FacetGrid(data=irisds, hue='Species', size=5)\
.map(plt.scatter,'SepalWidthCm','PetalWidthCm')\
.add_legend()

# %% [markdown]
# **Box Plot**

# %%
irisds.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
d1=plt.gcf()
d1.set_size_inches(10,7)
d1=sns.boxplot(x='Species',y='SepalLengthCm',data=irisds,order=['Iris-virginica','Iris-versicolor','Iris-setosa'],linewidth=2.5,orient='v',dodge=False)

# %%
#irisds.drop("Id", axis=1).boxplot(by="Species", figsize=(12, 8))
irisds.boxplot(by="Species", figsize=(12, 8))
# Out:
# array([[<AxesSubplot:title={'center':'PetalLengthCm'}, xlabel='[Species]'>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}, xlabel='[Species]'>],
#        [<AxesSubplot:title={'center':'SepalLengthCm'}, xlabel='[Species]'>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %% [markdown]
# **Strip Plot of 15 inches wide and 10 inches tall**

# %%
d2=plt.gcf()
d2.set_size_inches(15,10)
d2=sns.stripplot(data=irisds, x='Species', y='PetalLengthCm', jitter=True, edgecolor='blue', size=8, palette='winter', orient='v')

# %% [markdown]
# **Box plot and stripp plot in one graph**

# %%
f1=plt.gcf()
f1.set_size_inches(10,5)
f1=sns.boxplot(data=irisds, x='Species', y='SepalWidthCm')
f1=sns.stripplot(data=irisds, x='Species', y='SepalWidthCm', jitter=True, edgecolor='gray')
plt.show()

# %%
f1=plt.gcf()
f1.set_size_inches(10,5)
f1=sns.boxplot(data=irisds, x='Species', y='PetalWidthCm')
f1=sns.stripplot(data=irisds, x='Species', y='PetalWidthCm', jitter=True, edgecolor='gray')
plt.show()

# %% [markdown]
# **Violin Plot**

# %%
d1=plt.gcf()
d1.set_size_inches(10,5)
d1=sns.violinplot (data=irisds, x='Species', y='SepalLengthCm')

# %%
d2=plt.gcf()
d2.set_size_inches(20,10)
d2=sns.violinplot(data=irisds, x='Species', y='SepalWidthCm')

# %%
d3=plt.gcf()
d3.set_size_inches(10,5)
d3=sns.violinplot(data=irisds, x='Species', y='PetalLengthCm')

# %% [markdown]
# **Pair Plot**

# %%
sns.pairplot(data=irisds, kind='scatter')

# %%
sns.pairplot(data=irisds, kind='hex')

# %%
sns.pairplot(data=irisds, kind='reg')

# %%
sns.pairplot(irisds, hue='Species');

# %%
sns.pairplot(irisds, hue='Species')

# %% [markdown]
# **Heat Map**

# %%
d4=plt.gcf()
d4.set_size_inches(10,7)
d4=sns.heatmap(irisds.corr(), annot=True, cmap='cubehelix', linewidths=1, linecolor='k', square=True, mask=False, vmin=-1, vmax=1, cbar_kws={"orientation":"vertical"}, cbar=True)

# %%
d4=plt.gcf()
d4.set_size_inches(10,7)
d4=sns.heatmap(irisds.corr(), annot=True, cmap='cubehelix')

# %%
d4=plt.gcf()
d4.set_size_inches(10,7)
d4=sns.heatmap(irisds.corr(), annot=False, cmap='cubehelix')

# %%
d4=plt.gcf()
d4.set_size_inches(10,7)
d4=sns.heatmap(irisds.corr(), annot=True, cmap='cubehelix', linewidths=1, linecolor='k', square=True, mask=False, cbar_kws={"orientation":"vertical"}, cbar=True)

# %% [markdown]
# **Distribution Plot**

# %%
d5=plt.gcf()
d5.set_size_inches(15,10)
d5=irisds.hist(edgecolor='black', linewidth=1.5)

# %%
d6=plt.gcf()
d6.set_size_inches(10,5)
d6=irisds.hist(edgecolor='Green',linewidth=0.5)

# %%
d6=plt.gcf()
d6.set_size_inches(10,5)
d6=irisds.hist(edgecolor='Orange',linewidth=0.5)

# %% [markdown]
# **Swarm Plot**

# %%
d7=plt.gcf()
d7.set_size_inches(10,8)
d7=sns.set(style='darkgrid')
d7=sns.swarmplot(data=irisds, x='Species', y='SepalWidthCm')

# %%
irisds
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
d8=plt.gcf()
d8.set_size_inches(10,5)
d8=sns.set(style='whitegrid')
ax=sns.violinplot(data=irisds, x='Species', y='SepalLengthCm', inner=None)
ax1=sns.swarmplot(data=irisds, x='Species', y='SepalWidthCm', color='white', edgecolor='black')

# %%
d8=plt.gcf()
d8.set_size_inches(10,5)
d8=sns.set(style='darkgrid')
ax=sns.violinplot(data=irisds, x='Species', y='SepalLengthCm', inner=None)
ax1=sns.swarmplot(data=irisds, x='Species', y='SepalWidthCm', color='white', edgecolor='grey')

# %%
d8=plt.gcf()
d8.set_size_inches(10,5)
d8=sns.set(style='darkgrid')
ax=sns.violinplot(data=irisds, x='Species', y='SepalLengthCm', inner='box')
ax1=sns.swarmplot(data=irisds, x='Species', y='SepalWidthCm', color='white', edgecolor='grey')

# %%
d8=plt.gcf()
d8.set_size_inches(10,5)
d8=sns.set(style='darkgrid')
ax=sns.violinplot(data=irisds, x='Species', y='PetalLengthCm', inner='box')
ax1=sns.swarmplot(data=irisds, x='Species', y='PetalWidthCm', color='white', edgecolor='grey')

# %% [markdown]
# **LM Plot**

# %%
sns.lmplot(data=irisds, x='PetalLengthCm', y='SepalLengthCm')

# %%
sns.lmplot(data=irisds, x='PetalLengthCm', y='PetalLengthCm')

# %% [markdown]
# **Facet Grid**

# %%
sns.FacetGrid(data=irisds, hue='Species', size=7) \
. map(sns.kdeplot,"PetalLengthCm") \
.add_legend()
plt.ioff()

# %%
sns.FacetGrid(irisds, hue='Species', size=8) \
.map(sns.kdeplot, "PetalWidthCm") \
.add_legend()
plt.ioff()

# %%
sns.FacetGrid (irisds, hue='Species', size=10) \
    .map(sns.kdeplot, "SepalLengthCm") \
    .add_legend()
plt.ioff()

# %%
sns.FacetGrid(data=irisds, hue='Species', size=10) \
.map(sns.kdeplot,"SepalLengthCm") \
.add_legend()
plt.ioff()

# %% [markdown]
# **Boxen Plot**

# %%
e1=plt.gcf()
e1.set_size_inches(10,7)
e1=sns.boxenplot(data=irisds, x='Species', y='SepalLengthCm')

# %%
sns.distplot(irisds['SepalLengthCm'],kde=True,bins=20)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalLengthCm'>

# %%
sub=irisds[irisds['Species']=='irisds-setosa']
sns.kdeplot(data=sub[['SepalLengthCm','SepalWidthCm']],cmap="plasma", shade=True, shade_lowest=False)
plt.title('irisds-setosa')
plt.xlabel('Sepal Length Cm')
plt.ylabel('Sepal Width Cm')
# Out:
# Text(43.756666015625015, 0.5, 'Sepal Width Cm')

# %%
irisds['Species'] = irisds['Species'].astype('category')

# %%
list1=list()
mylabels=list()
for gen in irisds.Species.cat.categories:
    list1.append(irisds[irisds.Species==gen].SepalLengthCm)
    mylabels.append(gen)
    
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %%
irisds['Species'] = irisds['Species'].astype('category')

# %%
sns.distplot(irisds['SepalLengthCm'],kde=True,bins=20);
